# %%
# Add relevant Jupyter notebook extensions 
# %load_ext autoreload
# %autoreload 2

# %%
# You can double-check your Python path like this...
import sys  
print(sys.path)
# Out:
# ['C:\\Users\\Calum\\Anaconda\\python312.zip', 'C:\\Users\\Calum\\Anaconda\\DLLs', 'C:\\Users\\Calum\\Anaconda\\Lib', 'C:\\Users\\Calum\\Anaconda', 'c:\\Users\\Calum\\.venvs\\B1-venv', '', 'c:\\Users\\Calum\\.venvs\\B1-venv\\Lib\\site-packages', 'c:\\Users\\Calum\\Desktop\\Engineering\\B1\\B1 - Practical\\b1-coding-practical-mt24']

# %% [markdown]
# # Simulate closed-loop
# After implementing your control functionality, you can simulate the closed-loop with code that looks something like this...

# %%
# Import relevant modules
from uuv_mission import Submarine, ClosedLoop, Mission, PDController, PIDController

# Instantiate your submarine model
sub = Submarine()

# Instantiate your controller (depending on your implementation)
controller_type = "PD"  # Choose between "PD" and "PID"

if controller_type == "PD": # Instantiate PD controller
    controller = PDController(Kp=0.15, Kd=0.6)
elif controller_type == "PID": # Instantiate PID controller
    controller = PIDController(Kp=0.15, Kd=0.6, Ki=0.05)

# Instantiate closed-loop system
closed_loop = ClosedLoop(sub, controller)

#You must implement this method in the Mission class
mission = Mission.from_csv("../data/mission.csv")  # Load mission data from data directory

# Simulate the closed-loop system with random disturbances and plot results
trajectory = closed_loop.simulate_with_random_disturbances(mission)
trajectory.plot_completed_mission(mission)
